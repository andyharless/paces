# %%
from get_training_data import *

import tensorflow as tf
import keras
import pickle
import gzip
import os
import matplotlib.pyplot as plt
# %matplotlib nbagg
# Out:
# /home/andy/.local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
nexample = 7
trues = []
falses = []
while len(trues)<nexample or len(falses)<nexample:
    song, tempo, compatible, clip = get_training_case()
    thelist = trues if compatible else falses
    if len(thelist)<nexample:
        thelist.append([song, tempo, clip_to_tf_input(resample_clip(clip)).mean(axis=2)])

# %%
for t in trues:
    print(t[:2])
    plt.imshow(t[2])
    plt.show()
# Out:
# ['CrocodileRock1', 76]
# ['DriveMyCar', 123]
# ['HeavenKnows1', 65]
# ['TakingCareOfBusiness', 66]
# ['IveJustSeenAFace', 120]
# ['DriveMyCar', 62]
# ['RespectMP', 225]

# %%
for f in falses:
    print(f[:2])
    plt.imshow(f[2])
    plt.show()
# Out:
# ['AllMyLoving', 67]
# ['FireAndIce', 152]
# ['DoReMi', 50]
# ['Girl', 41]
# ['TheLoveYouSave', 51]
# ['DirkBalthausTrioMelAndChloe', 88]
# ['FireAndRain2MP', 50]

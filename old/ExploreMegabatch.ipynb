# %%
from get_training_data import *

import tensorflow as tf
import keras
import pickle
import gzip
import os
import random
import matplotlib.pyplot as plt
# %matplotlib nbagg
# Out:
# /home/andy/.local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
with gzip.open('train_cases.pkl.gz','rb') as fp:
    train_cases = pickle.load(fp)
type(train_cases), len(train_cases)
# Out:
# (tuple, 2)

# %%
train_X = train_cases[0]
train_y = train_cases[1]
ntrain = train_X.shape[0]
type(train_X), train_X.shape, train_X.dtype, type(train_y), train_y.shape, train_y.dtype
# Out:
# (numpy.ndarray,
#  (16384, 16, 16, 128),
#  dtype('float32'),
#  numpy.ndarray,
#  (16384, 1),
#  dtype('float64'))

# %%
flat = train_X.reshape(-1)
flat.shape
# Out:
# (536870912,)

# %%
plt.hist(flat)
plt.show()

# %%
plt.hist(flat[flat<500])
plt.show()

# %%
plt.hist(flat[flat<100])
plt.show()

# %%
plt.hist(flat[flat<50])
plt.show()

# %%
plt.hist(flat[flat<10])
plt.show()

# %%
plt.hist(flat[flat<2])
plt.show()

# %%
np.min(flat), np.max(flat)
# Out:
# (1.10588405e-11, 3285.9644)

# %%
plt.hist(np.log(1e-3+flat))
plt.show()

# %%
plt.hist(np.log(1e-4+flat))
plt.show()

# %%
plt.hist(np.log(1e-5+flat))
plt.show()

# %%
plt.hist(np.log(1e-6+flat))
plt.show()

# %%
plt.hist(np.log(3e-6+flat))
plt.show()

# %%
np.median(flat)
# Out:
# 0.07714115

# %%
np.log(.0771)
# Out:
# -2.562651998412853

# %% [markdown]
# Conclusion: To preprocess, add <code>1e-5</code>, take <code>log</code>, add <code>2.5</code>, and divide by <code>5</code>

# %%
plt.hist((np.log(1e-5+flat)+2.5)/5)
plt.show()
